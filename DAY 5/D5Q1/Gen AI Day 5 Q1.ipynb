# %%
from google.colab import userdata
api_key=userdata.get('GEMINI_AIP_KEY')

# %%
from google import genai

client = genai.Client(api_key=api_key)

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="My name is Jithendiraa Senthilkumar"
)
print(interaction.output_text)
# Out:
# Hello Jithendiraa Senthilkumar! It is a pleasure to meet you. How can I help you today?

# %%
interaction2 = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Explain Generative AI in 50 words"
)

# %%
interaction2.text
# Out:
# 'Generative AI is a branch of artificial intelligence that creates new content, including text, images, music, and code. By learning patterns from vast amounts of existing data, these algorithms generate original, realistic outputs in response to user prompts, transforming how we work, write, design, learn, and solve complex problems daily.'

# %%
interaction3 = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Explain Machine Learning in 50 words"
)

# %%
interaction3.text
# Out:
# 'Machine learning is a branch of artificial intelligence where computers learn from data instead of relying on explicit programming. By analyzing information, algorithms detect patterns and make independent decisions. As they process more data, these systems continuously improve their accuracy and performance over time, mimicking how humans learn from experience.'
